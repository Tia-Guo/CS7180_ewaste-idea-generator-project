# %% [markdown]
# <a href="https://colab.research.google.com/github/Tia-Guo/CS7180_ewaste-idea-generator-project/blob/main/test_CoT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""
AI-Generated Email Evaluation System
Implements 6 evaluation metrics based on research framework
"""

# ============================================================================
# INSTALLATION & SETUP
# ============================================================================

# Install required packages
# !pip install openai anthropic google-generativeai sentence-transformers scikit-learn pandas numpy tenacity -q

import os
import json
import time
import pandas as pd
import numpy as np
from typing import Dict, List, Tuple
from dataclasses import dataclass
from sklearn.cluster import KMeans
from sentence_transformers import SentenceTransformer
import openai
from anthropic import Anthropic
from tenacity import retry, stop_after_attempt, wait_random_exponential

# ============================================================================
# CONFIGURATION
# ============================================================================

class Config:
    """Configuration for API keys and model selection"""

    # ============================================================================
    # OPENROUTER CONFIGURATION
    # ============================================================================
    # Set your OpenRouter API key here
    OPENROUTER_API_KEY = "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"

    # OpenRouter base URL
    OPENROUTER_BASE_URL = "https://openrouter.ai/api/v1"

    # Choose your model from OpenRouter's catalog
    # Examples:
    # - "openai/gpt-4o"
    # - "anthropic/claude-sonnet-4"
    # - "google/gemini-2.5-flash"
    # - "anthropic/claude-3.5-haiku"
    # - "openai/gpt-4o-mini"
    # - "google/gemma-3-4b-it"
    EVALUATION_MODEL = "x-ai/grok-4-fast"

    # Semantic entropy settings
    N_SEMANTIC_SAMPLES = 5  # Number of outputs to generate for semantic entropy

    # API Pricing (USD per 1M tokens) - OpenRouter pricing
    PRICING = {
        # OpenAI Models
        'openai/gpt-5': {'input': 1.25, 'output': 10.0},
        'openai/gpt-5-chat': {'input': 1.25, 'output': 10.0},
        'openai/gpt-4o': {'input': 2.5, 'output': 10.0},
        'openai/gpt-4-turbo': {'input': 10.0, 'output': 30.0},
        'openai/gpt-4o-mini': {'input': 0.15, 'output': 0.6},

        # Anthropic Models
        'anthropic/claude-sonnet-4': {'input': 3.0, 'output': 15.0},
        'anthropic/claude-3.5-haiku': {'input': 0.8, 'output': 4.0},
        'anthropic/claude-3-haiku': {'input': 0.25, 'output': 1.25},

        # Google Models
        'google/gemini-2.5-flash': {'input': 0.3, 'output': 2.5},
        'google/gemini-2.5-pro': {'input': 1.25, 'output': 10.0},
        'google/gemma-3-4b-it': {'input': 0.017, 'output': 0.068},

        # Qwen Models
        'qwen/qwen-2.5-72b-instruct': {'input': 0.35, 'output': 0.4},
        'qwen/qwen2.5-vl-72b-instruct': {'input': 0.0, 'output': 0.0},
        'qwen/qwen3-coder-30b-a3b-instruct': {'input': 0.06, 'output': 0.25},

        # Meta Models
        'meta-llama/llama-3.3-70b-instruct': {'input': 0.35, 'output': 0.4},
        'meta-llama/llama-3.1-8b-instruct': {'input': 0.02, 'output': 0.03},

        # Mistral Models
        'mistralai/mistral-small-3.2-24b-instruct:free': {'input': 0.0, 'output': 0.0},

        # xAI Models
        'x-ai/grok-4-fast': {'input': 0.20, 'output': 0.50},

        # Amazon Models
        'amazon/nova-micro-1.0': {'input': 0.035, 'output': 0.14},

        # DeepSeek Models
        'deepseek/deepseek-chat-v3-0324': {'input': 0.24, 'output': 0.84},
        'deepseek/deepseek-v3': {'input': 0.3, 'output': 0.85},

        # Llama Models:
        'sao10k/l3-lunaris-8b': {'input': 0.04, 'output': 0.05},
    }

    @classmethod
    def setup(cls):
        """Setup OpenRouter client"""
        client = openai.OpenAI(
            api_key=cls.OPENROUTER_API_KEY,
            base_url=cls.OPENROUTER_BASE_URL,
            default_headers={
                "HTTP-Referer": "https://github.com/yourusername/email-eval",
                "X-Title": "Email Evaluation System",
            }
        )
        return {
            'openai': client,
            'openrouter': client
        }

    @classmethod
    def get_model_cost(cls, model: str, input_tokens: int, output_tokens: int) -> float:
        """Calculate cost for a model call"""
        if model not in cls.PRICING:
            print(f"⚠️  Warning: No pricing info for model '{model}'. Cost tracking disabled.")
            return 0.0
        pricing = cls.PRICING[model]
        input_cost = (input_tokens / 1_000_000) * pricing['input']
        output_cost = (output_tokens / 1_000_000) * pricing['output']
        return input_cost + output_cost


# ============================================================================
# DATA STRUCTURES
# ============================================================================

@dataclass
class EvaluationResult:
    """Store evaluation results for a single email"""
    hallucination_score: int
    cta_quality: int
    language_quality: int
    personalization: int
    human_likeness: int
    instruction_adherence: int
    overall_score: float
    is_acceptable: bool
    detailed_feedback: Dict
    total_cost: float
    input_tokens: int
    output_tokens: int
    api_calls: int

    def to_dict(self):
        return {
            'hallucination_score': self.hallucination_score,
            'cta_quality': self.cta_quality,
            'language_quality': self.language_quality,
            'personalization': self.personalization,
            'human_likeness': self.human_likeness,
            'instruction_adherence': self.instruction_adherence,
            'overall_score': self.overall_score,
            'is_acceptable': self.is_acceptable,
            'total_cost_usd': self.total_cost,
            'input_tokens': self.input_tokens,
            'output_tokens': self.output_tokens,
            'api_calls': self.api_calls,
            'detailed_feedback': self.detailed_feedback
        }


# ============================================================================
# LLM-AS-JUDGE EVALUATOR
# ============================================================================

class LLMEvaluator:
    """
    Uses LLM-as-judge approach for evaluating email quality
    Works with OpenRouter API
    """

    def __init__(self, model: str = Config.EVALUATION_MODEL):
        self.model = model
        self.clients = Config.setup()
        self.client = self.clients['openrouter']
        self.total_input_tokens = 0
        self.total_output_tokens = 0
        self.total_api_calls = 0
        self.total_cost = 0.0

    @retry(wait=wait_random_exponential(multiplier=1, max=60), stop=stop_after_attempt(3))
    def _call_llm(self, prompt: str) -> Tuple[str, int, int]:
        try:
            response = self.client.chat.completions.create(
                model=self.model,
                messages=[{"role": "user", "content": prompt}],
                temperature=0.3,
                response_format={"type": "json_object"}
            )
            input_tokens = response.usage.prompt_tokens
            output_tokens = response.usage.completion_tokens
            content = response.choices[0].message.content
            self.total_input_tokens += input_tokens
            self.total_output_tokens += output_tokens
            self.total_api_calls += 1
            cost = Config.get_model_cost(self.model, input_tokens, output_tokens)
            self.total_cost += cost
            return content, input_tokens, output_tokens
        except openai.APIError as e:
            print(f"❌ API Error calling OpenRouter API: {e}")
            raise
        except Exception as e:
            print(f"❌ Error calling OpenRouter API: {e}")
            raise

    def reset_usage(self):
        self.total_input_tokens = 0
        self.total_output_tokens = 0
        self.total_api_calls = 0
        self.total_cost = 0.0

    def get_usage_stats(self) -> Dict:
        return {
            'total_input_tokens': self.total_input_tokens,
            'total_output_tokens': self.total_output_tokens,
            'total_api_calls': self.total_api_calls,
            'total_cost_usd': round(self.total_cost, 4)
        }

    @staticmethod
    def safe_json_loads(text: str):
        import json, re
        if not text or not text.strip():
            raise ValueError("Empty LLM response")
        s = text.strip()
        if s.startswith("```"):
            s = s.strip("` \n")
            if s.lower().startswith("json"):
                s = s[4:].strip()
        try:
            return json.loads(s)
        except json.JSONDecodeError:
            pass
        start, end = s.find("{"), s.rfind("}")
        if 0 <= start < end:
            snippet = s[start:end + 1]
            try:
                return json.loads(snippet)
            except json.JSONDecodeError:
                pass
        s2 = re.sub(r"(?<!\\)'", '"', s)
        return json.loads(s2)

# ============================================================================
# HA EVALUATOR
# ============================================================================

    def evaluate_hallucination(self, email: str, user_prompt: str) -> Tuple[int, str]:
        """Evaluate Hallucination (Binary Score: 0 or 1) using Chain-of-Thought Prompting"""

        # === One-Shot  ===
        example_email = """Hi Lubaina,

Saw recent interest in content around targeted advertising and account-based strategies. It seems you may be digging into ways to drive stronger campaign performance.

It’s hard to act on anonymous site visits when you can’t tailor the message or re-engage them later.

Demandbase shows which companies visit your site and adapts the experience in real time. That means deeper engagement and less wasted spend.

Open to a 15-min chat to see if this is worth your time?
"""

        example_output = """{
  "score": 0,
  "reasoning": "The email only uses information found in the provided JSON (intent keywords, company, and Demandbase features). No fabricated facts are introduced."
}"""

        # ===  CoT Prompt ===
        prompt = f"""You are an evaluator that detects hallucinations in AI-generated emails.

Let's think step by step before deciding the score.

Follow this reasoning process:
1. Identify all factual statements or claims in the email.
2. Compare these statements with the provided JSON or user prompt.
3. Determine whether any claim lacks source support or introduces new fabricated information.
4. Assess whether such fabrication would affect accuracy or trustworthiness.
5. Decide the binary score and summarize your reasoning briefly.

Example Email:
{example_email}

Example Evaluation Output (JSON):
{example_output}

Now evaluate the following email using the same logic and reasoning steps.

Email:
{email}

{f"user_prompt: {user_prompt}" if user_prompt else ""}

Scoring:
0: No Critical Failure — The output contains no fabricated information.
1: Critical Failure Present — The output includes false or unsupported information not in the JSON or prompt.

Respond only with a JSON object:
{{
  "score": 0 or 1,
  "reasoning": "Concise explanation of your reasoning."
}}
"""

        # === 调用 LLM  ===
        response_text, _, _ = self._call_llm(prompt)
        try:
            result = self.safe_json_loads(response_text)
            return result.get('score', -1), result.get('reasoning', 'No reasoning found')
        except Exception as e:
            print(f"❌ JSON Decode Error: {e}")
            print(f"Raw LLM response: {response_text}")
            return -1, f"Error parsing LLM response: {response_text[:200]}..."


# ============================================================================
# CTA EVALUATOR
# ============================================================================

    def evaluate_cta_quality(self, email: str) -> Tuple[int, str]:
        """Evaluate Call-to-Action (CTA) quality (1-5 scale) using Chain-of-Thought Prompting"""

        #===  One-Shot ===
        example_email = """Hi Lubaina,

Saw recent interest in content around targeted advertising and account-based strategies. It seems you may be digging into ways to drive stronger campaign performance.

It’s hard to act on anonymous site visits when you can’t tailor the message or re-engage them later.

Demandbase shows which companies visit your site and adapts the experience in real time. That means deeper engagement and less wasted spend.

Open to a 15-min chat to see if this is worth your time?
"""

        example_output = """{
  "score": 5,
  "reasoning": "The CTA ('Would you like to see a quick demo next week?') is clear, low-friction, and directly supports the email's purpose. It fits naturally and encourages an easy next step."
}"""

        # ===  CoT Prompt ===
        prompt = f"""You are an evaluator assessing the quality of a Call-to-Action (CTA) in sales emails.

Let's think step by step before scoring.

Reasoning steps:
1. Identify the CTA phrase or sentence.
2. Check if it clearly communicates the desired next step.
3. Evaluate its relevance to the email’s purpose.
4. Assess how natural, compelling, and low-friction it feels.
5. Assign a score (1–5) and summarize your reasoning.

Example Email:
{example_email}

Example Evaluation Output (JSON):
{example_output}

Now analyze this email:

Email:
{email}

Scoring:
5: Excellent — Compelling, low-friction, natural CTA aligned with the goal.
4: Good — Clear and relevant but could be more persuasive.
3: Average — Functional but generic or weak.
2: Poor — Vague or contextually mismatched.
1: Very Poor — Missing or inappropriate CTA.

Respond only with JSON:
{{
  "score": 1–5,
  "reasoning": "Brief step-by-step summary of why you assigned this score."
}}
"""

        response_text, _, _ = self._call_llm(prompt)
        try:
            result = self.safe_json_loads(response_text)
            return result.get('score', -1), result.get('reasoning', 'No reasoning found')
        except Exception as e:
            print(f"❌ JSON Decode Error: {e}")
            print(f"Raw LLM response: {response_text}")
            return -1, f"Error parsing LLM response: {response_text[:200]}..."


# ============================================================================
# LQ EVALUATOR
# ============================================================================

    def evaluate_language_quality(self, email: str) -> Tuple[int, str]:
        """Evaluate language quality and coherence (1-5 scale) using Chain-of-Thought Prompting"""

        # === One-Shot ===
        example_email = """Hi Lubaina,

Saw recent interest in content around targeted advertising and account-based strategies...
"""

        example_output = """{
  "score": 5,
  "reasoning": "Strong grammar, clear structure, and fluent tone. Sentences are varied and concise."
}"""

        # === CoT Prompt ===
        prompt = f"""You are an evaluator assessing the language quality and coherence of sales emails.

Let's think step by step before giving a score.

Follow this reasoning chain:
1. Identify grammar, spelling, and punctuation issues.
2. Assess vocabulary appropriateness and readability.
3. Evaluate sentence structure and flow.
4. Check for conciseness and formatting clarity.
5. Summarize and assign a score from 1–5.

Example Email:
{example_email}

Example Evaluation Output (JSON):
{example_output}

Now analyze the following email:

Email:
{email}

Scoring:
5: Excellent — Fluent, natural, no major errors.
4: Good — Minor errors or slight repetition.
3: Average — Some awkward phrasing or structural issues.
2: Poor — Noticeable grammatical or stylistic errors.
1: Very Poor — Hard to read or poorly structured.

Respond only with:
{{
  "score": 1–5,
  "reasoning": "Concise explanation summarizing your reasoning chain."
}}
"""

        response_text, _, _ = self._call_llm(prompt)
        try:
            result = self.safe_json_loads(response_text)
            return result.get('score', -1), result.get('reasoning', 'No reasoning found')
        except Exception as e:
            print(f"❌ JSON Decode Error: {e}")
            print(f"Raw LLM response: {response_text}")
            return -1, f"Error parsing LLM response: {response_text[:200]}..."


# ============================================================================
# PERSONALIZATION EVALUATOR
# ============================================================================

    def evaluate_personalization(self, email: str, recipient_data: Dict) -> Tuple[int, str]:
        """Evaluate personalization quality (1-5 scale) using Chain-of-Thought Prompting"""

        # === One-Shot ===
        example_email = """Hi Lubaina,

Saw recent interest in content around targeted advertising...
"""

        example_output = """{
  "score": 5,
  "reasoning": "Uses recipient's interests and intent signals naturally, with relevant context and tone."
}"""

        # === CoT Prompt ===
        prompt = f"""You are an evaluator assessing how well this email is personalized.

Let's think step by step before scoring.

Reasoning process:
1. Identify references to recipient or their company.
2. Check whether personalization uses specific, relevant details (e.g., industry, role, behavior).
3. Evaluate if these details are naturally integrated or forced.
4. Assess the relevance and value provided to the recipient.
5. Decide the score (1–5) and summarize reasoning.

Example Email:
{example_email}

Example Output:
{example_output}

Now evaluate this email.

Email:
{email}

Recipient Data:
{json.dumps(recipient_data, indent=2)}

Scoring:
5: Deep, natural personalization.
4: Good personalization, minor generalization.
3: Some relevance but generic tone.
2: Minimal relevance.
1: None — completely generic.

Respond with JSON:
{{
  "score": 1–5,
  "reasoning": "Concise explanation of your reasoning chain."
}}
"""

        response_text, _, _ = self._call_llm(prompt)
        try:
            result = self.safe_json_loads(response_text)
            return result.get('score', -1), result.get('reasoning', 'No reasoning found')
        except Exception as e:
            print(f"❌ JSON Decode Error: {e}")
            print(f"Raw LLM response: {response_text}")
            return -1, f"Error parsing LLM response: {response_text[:200]}..."


# ============================================================================
# HL EVALUATOR
# ============================================================================

    def evaluate_human_likeness(self, email: str) -> Tuple[int, str]:
        """Evaluate human-likeness (1-5 scale) using Chain-of-Thought Prompting"""

        # === One-Shot ===
        example_email = """Hi Lubaina,
Saw recent interest in targeted advertising...
"""

        example_output = """{
  "score": 5,
  "reasoning": "Tone feels natural and conversational; varied sentence structure and emotional authenticity."
}"""

        # === CoT Prompt ===
        prompt = f"""You are an evaluator determining how human-like this email sounds.

Let's think step by step before scoring.

Reasoning process:
1. Assess tone for conversational naturalness.
2. Check sentence rhythm and word variety.
3. Identify emotional authenticity and balance.
4. Evaluate flow and readability.
5. Assign a final score and summarize your reasoning.

Example Email:
{example_email}

Example Output:
{example_output}

Now analyze the following email:

Email:
{email}

Scoring:
5: Highly human-like — smooth, conversational, emotionally real.
4: Mostly human-like — natural with small stiffness.
3: Neutral — could be human or AI.
2: Likely AI — robotic phrasing or formulaic tone.
1: Clearly AI — unnatural vocabulary and rhythm.

Respond only with JSON:
{{
  "score": 1–5,
  "reasoning": "Short explanation summarizing your reasoning steps."
}}
"""

        response_text, _, _ = self._call_llm(prompt)
        try:
            result = self.safe_json_loads(response_text)
            return result.get('score', -1), result.get('reasoning', 'No reasoning found')
        except Exception as e:
            print(f"❌ JSON Decode Error: {e}")
            print(f"Raw LLM response: {response_text}")
            return -1, f"Error parsing LLM response: {response_text[:200]}..."


# ============================================================================
# INSTRUCTION ADHERENCE EVALUATOR
# ============================================================================

    def evaluate_instruction_adherence(self, email: str, instructions: str, user_prompt: str) -> Tuple[int, str]:
        """Evaluate adherence to given instructions (1-5 scale) using Chain-of-Thought Prompting"""

        # === One-Shot ===
        example_email = """Hi Lubaina,
Saw recent interest in targeted advertising...
"""

        example_output = """{
  "score": 5,
  "reasoning": "Email follows tone, length, and structure rules perfectly with no extra content."
}"""

        # === CoT Prompt ===
        prompt = f"""You are an evaluator checking how well an email follows the given instructions.

Let's think step by step before giving the score.

Reasoning process:
1. Identify key rules or constraints from the instructions.
2. Compare the email against these requirements.
3. Note any deviations, missing elements, or extra content.
4. Evaluate tone, style, and goal alignment.
5. Assign a score (1–5) and summarize reasoning.

Example Email:
{example_email}

Example Output:
{example_output}

Now analyze this email.

Email:
{email}

Instructions:
{instructions}

User Prompt:
{user_prompt}

Scoring:
5: Fully adheres to all rules.
4: Mostly adheres with small deviations.
3: Some adherence but noticeable misses.
2: Poor adherence, several rule breaks.
1: Fails to follow instructions.

Respond only with JSON:
{{
  "score": 1–5,
  "reasoning": "Concise summary of reasoning steps and decision."
}}
"""

        response_text, _, _ = self._call_llm(prompt)
        try:
            result = self.safe_json_loads(response_text)
            return result.get('score', -1), result.get('reasoning', 'No reasoning found')
        except Exception as e:
            print(f"❌ JSON Decode Error: {e}")
            print(f"Raw LLM response: {response_text}")
            return -1, f"Error parsing LLM response: {response_text[:200]}..."


# ============================================================================
# MAIN EVALUATION PIPELINE
# ============================================================================

class EmailEvaluationPipeline:
    """
    Complete evaluation pipeline for AI-generated emails
    Works with OpenRouter API
    """

    def __init__(self, model: str = Config.EVALUATION_MODEL):
        self.llm_eval = LLMEvaluator(model)
        self.clients = Config.setup()
        self.openrouter_client = self.clients['openrouter']

    def evaluate_email(
        self,
        email: str,
        instructions: str = "",
        user_prompt: str = "",
        recipient_data: Dict = None,
        context: str = "",
        check_hallucination: bool = True
    ) -> EvaluationResult:
        start_time = time.time()
        print("Starting evaluation...")
        detailed_feedback = {}
        self.llm_eval.reset_usage()

        print("Evaluating Hallucination Detection...")
        hi_score, hi_reasoning = self.llm_eval.evaluate_hallucination(email, user_prompt)
        detailed_feedback['hallucination'] = hi_reasoning
        print(f"HI score: {hi_score} — reason: {hi_reasoning[:200]}")

        print("Evaluating CTA quality...")
        cta_score, cta_reasoning = self.llm_eval.evaluate_cta_quality(email)
        detailed_feedback['cta'] = cta_reasoning

        print("Evaluating language quality...")
        lq_score, lq_reasoning = self.llm_eval.evaluate_language_quality(email)
        detailed_feedback['language_quality'] = lq_reasoning

        print("Evaluating personalization...")
        if recipient_data:
            per_score, per_reasoning = self.llm_eval.evaluate_personalization(email, recipient_data)
        else:
            per_score, per_reasoning = 5, "No recipient data provided"
        detailed_feedback['personalization'] = per_reasoning

        print("Evaluating human-likeness...")
        hl_score, hl_reasoning = self.llm_eval.evaluate_human_likeness(email)
        detailed_feedback['human_likeness'] = hl_reasoning

        print("Evaluating instruction adherence...")
        if instructions:
            ia_score, ia_reasoning = self.llm_eval.evaluate_instruction_adherence(email, instructions, user_prompt)
        else:
            ia_score, ia_reasoning = 5, "No instructions provided"
        detailed_feedback['instruction_adherence'] = ia_reasoning

        usage_stats = self.llm_eval.get_usage_stats()
        scores = [cta_score, lq_score, per_score, hl_score, ia_score]
        valid_scores = [score for score in scores if score != -1]
        overall_score = np.mean(valid_scores) if valid_scores else 0

        is_acceptable = (
            (hi_score == 0 or hi_score == -1)
            and overall_score >= 3
            and lq_score >= 2
        )

        elapsed_time = time.time() - start_time
        detailed_feedback['runtime_seconds'] = elapsed_time

        print(f"\nEvaluation complete!")
        print(f"💰 Cost: ${usage_stats['total_cost_usd']:.4f}")
        print(f"📊 Tokens: {usage_stats['total_input_tokens']} in / {usage_stats['total_output_tokens']} out")
        print(f"🔄 API Calls: {usage_stats['total_api_calls']}")
        print(f"⏱️ Runtime: {elapsed_time:.2f} seconds")

        return EvaluationResult(
            hallucination_score=hi_score,
            cta_quality=cta_score,
            language_quality=lq_score,
            personalization=per_score,
            human_likeness=hl_score,
            instruction_adherence=ia_score,
            overall_score=overall_score,
            is_acceptable=is_acceptable,
            detailed_feedback=detailed_feedback,
            total_cost=usage_stats['total_cost_usd'],
            input_tokens=usage_stats['total_input_tokens'],
            output_tokens=usage_stats['total_output_tokens'],
            api_calls=usage_stats['total_api_calls']
        )

    def evaluate_batch(
        self,
        emails: List[Dict],
        check_hallucination: bool = False
    ) -> pd.DataFrame:
        results = []
        total_cost = 0.0
        batch_start = time.time()

        for i, email_data in enumerate(emails):
            print(f"\n{'='*60}")
            print(f"Evaluating email {i+1}/{len(emails)}")
            print(f"{'='*60}")

            result = self.evaluate_email(
                email=email_data['email'],
                instructions=email_data.get('instructions', ''),
                user_prompt=email_data.get('user_prompt', ''),
                recipient_data=email_data.get('recipient_data'),
                context=email_data.get('context', ''),
                check_hallucination=check_hallucination
            )

            total_cost += result.total_cost
            results.append({
                'email_id': i,
                **result.to_dict(),
                'runtime_seconds': result.detailed_feedback.get('runtime_seconds', None)
            })

        print(f"\n{'='*60}")
        print("BATCH EVALUATION SUMMARY")
        print(f"{'='*60}")
        print(f"Total emails evaluated: {len(emails)}")
        print(f"💰 Total cost: ${total_cost:.4f}")
        print(f"💰 Average cost per email: ${total_cost/len(emails):.4f}")
        print(f"💰 Cost for 10,000 emails: ${(total_cost/len(emails))*10000:.2f}")
        batch_elapsed = time.time() - batch_start
        print(f"🕒 Total batch runtime: {batch_elapsed:.2f} seconds")
        print(f"⏳ Average runtime per email: {batch_elapsed/len(emails):.2f} seconds")

        return pd.DataFrame(results)
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 357.5/357.5 kB 7.7 MB/s eta 0:00:00

# %%
# ============================================================================
# DATA LOADING FUNCTIONS
# ============================================================================

def load_test_data_from_file(file_path: str) -> List[Dict]:
    """
    Load test data from an external file.

    Supported formats:
    - JSON (.json): a JSON array containing test data

    Args:
        file_path: Path to the data file

    Returns:
        List of test data dictionaries
    """
    if not os.path.exists(file_path):
        raise FileNotFoundError(f"❌ File not found: {file_path}")

    file_ext = os.path.splitext(file_path)[1].lower()

    try:
        if file_ext == '.json':
            with open(file_path, 'r', encoding='utf-8') as f:
                data = json.load(f)
        else:
            raise ValueError(f"❌ Unsupported file format: {file_ext}. Supported format: .json")

        # Validate data structure
        required_fields = ['email']
        for i, item in enumerate(data):
            for field in required_fields:
                if field not in item:
                    raise ValueError(f"❌ Missing required field '{field}' in item {i}")

        print(f"✅ Successfully loaded {len(data)} test samples")
        return data

    except Exception as e:
        print(f"❌ Failed to load test data: {e}")
        raise


# ============================================================================
# MAIN TEST FUNCTIONS
# ============================================================================

def test_spreadsheet_examples(file_path: str):
    """Run evaluation pipeline on external test data from a JSON file"""

    print("\n" + "="*80)
    print("🧪 TESTING WITH EXTERNAL TEST DATA")
    print("="*80)

    # Load test data
    print(f"📁 Loading test data from file: {file_path}")
    test_data = load_test_data_from_file(file_path)

    if not test_data:
        print("❌ No test data found")
        return None

    # Initialize the evaluation pipeline
    try:
        pipeline = EmailEvaluationPipeline(model=Config.EVALUATION_MODEL)
    except Exception as e:
        print(f"\n❌ Error: Unable to initialize evaluation pipeline - {e}")
        return None

    # Evaluate all examples
    results_list = []

    for example in test_data:
        print(f"\n{'='*80}")
        print(f"📧 EVALUATING EXAMPLE {example.get('id', 'Unknown')}")
        recipient_data = example.get('recipient_data', {})
        print(f"Recipient: {recipient_data.get('name', 'Unknown')} - {recipient_data.get('role', 'Unknown')}")
        print(f"{'='*80}")

        # Print the email being evaluated
        print("\n📧 EMAIL BEING EVALUATED:")
        print("-" * 80)
        print(example['email'])
        print("-" * 80)

        # Print the evaluation context
        print("\n📋 EVALUATION CONTEXT:")
        print(f"Recipient Data: {recipient_data}")
        print(f"Context: {example.get('context', 'No context')}")
        print(f"Instructions: {example.get('instructions', 'No instructions provided')}")
        print(f"User Prompt: {example.get('user_prompt', 'No user prompt provided')}")


        result = pipeline.evaluate_email(
            email=example['email'],
            instructions=example.get('instructions', ''),
            user_prompt=example.get('user_prompt', ''),
            recipient_data=recipient_data,
            context=example.get('context', ''),
            check_hallucination=False  # disable for faster testing
        )

        results_list.append({
            'example_id': example.get('id', 'Unknown'),
            # 'recipient': recipient_data.get('name', 'Unknown'), # Removed recipient
            'overall_score': result.overall_score,
            'acceptable': result.is_acceptable,
            'hallucination': result.hallucination_score,
            'cta_quality': result.cta_quality,
            'language_quality': result.language_quality,
            'personalization': result.personalization,
            'human_likeness': result.human_likeness,
            'instruction_adherence': result.instruction_adherence,
            'cost_usd': result.total_cost
        })

    # Summary
    print("\n\n" + "="*80)
    print("📊 TEST RESULTS SUMMARY")
    print("="*80)

    df = pd.DataFrame(results_list)
    print(df.to_string(index=False))

    total_cost = df['cost_usd'].sum()
    avg_score = df['overall_score'].mean()
    acceptable_count = df['acceptable'].sum()

    print(f"\n{'='*80}")
    print(f"💰 Total Cost: ${total_cost:.4f}")
    print(f"💰 Average Cost per Email: ${total_cost/len(test_data):.4f}")
    print(f"💰 Estimated Cost for 10,000 emails: ${(total_cost/len(test_data))*10000:.2f}")
    print(f"\n📈 Average Overall Score: {avg_score:.2f}/10")
    print(f"✅ Acceptable Emails: {acceptable_count}/{len(test_data)} ({acceptable_count/len(test_data)*100:.0f}%)")
    print(f"{'='*80}\n")

    return df


def analyze_specific_example(file_path: str, example_id: int = 0):
    """Run detailed evaluation on a specific example"""

    print("\n" + "="*80)
    print(f"🔍 DETAILED ANALYSIS: EXAMPLE {example_id}")
    print("="*80)

    # Load test data
    test_data = load_test_data_from_file(file_path)

    # Find the specific example
    example = None
    for item in test_data:
        if item.get('id') == example_id:
            example = item
            break

    if not example:
        print(f"❌ Example with ID {example_id} not found")
        return None

    print("\n📧 EMAIL BEING EVALUATED:")
    print("-" * 80)
    print(example['email'])
    print("-" * 80)

    print("\n📋 EVALUATION CONTEXT:")
    recipient_data = example.get('recipient_data', {})
    print(f"Recipient: {recipient_data.get('name', 'Unknown')}")
    print(f"Role: {recipient_data.get('role', 'Unknown')}")
    print(f"Company: {recipient_data.get('company', 'Unknown')}")
    print(f"Context: {example.get('context', 'No context')}")

    print("\n📝 INSTRUCTIONS GIVEN:")
    print(example.get('instructions', 'No instructions provided'))

    pipeline = EmailEvaluationPipeline(model=Config.EVALUATION_MODEL)

    result = pipeline.evaluate_email(
        email=example['email'],
        instructions=example.get('instructions', ''),
        user_prompt=example.get('user_prompt', ''),
        recipient_data=recipient_data,
        context=example.get('context', ''),
        check_hallucination=False
    )

    print("\n" + "="*80)
    print("📊 EVALUATION RESULTS")
    print("="*80)
    print(f"Overall Score: {result.overall_score:.1f}/10")
    print(f"Acceptable: {'✅ YES' if result.is_acceptable else '❌ NO'}")
    print(f"\nBreakdown:")
    print(f"  CTA Quality: {result.cta_quality}/10")
    print(f"  Language Quality: {result.language_quality}/10")
    print(f"  personalization: {result.personalization}/10")
    print(f"  Human-likeness: {result.human_likeness}/10")
    print(f"  Instruction Adherence: {result.instruction_adherence}/10")
    print(f"\n💰 Cost: ${result.total_cost:.4f}")

    print("\n" + "="*80)
    print("💬 DETAILED FEEDBACK")
    print("="*80)
    for criterion, feedback in result.detailed_feedback.items():
        print(f"\n{criterion.upper()}:")
        if isinstance(feedback, dict):
            for key, value in feedback.items():
                print(f"  {key}: {value}")
        else:
            print(f"  {feedback}")

    return result


# ============================================================================
# MAIN EXECUTION ENTRY POINT
# ============================================================================

if __name__ == "__main__":
    print("\n🚀 Starting Email Evaluation System...")

    # Hardcoded file path for Colab
    file_path = "/content/30_test_long.json"

    # Choose the mode you want: batch or specific analysis
    # Set this manually for now
    RUN_BATCH_TEST = True   # Set to False if you want to analyze a specific example
    EXAMPLE_ID = 0          # Only used if RUN_BATCH_TEST is False

    if RUN_BATCH_TEST:
        print(f"\n🧪 Running batch test from: {file_path}")
        results_df = test_spreadsheet_examples(file_path=file_path)
    else:
        print(f"\n🔍 Running detailed analysis on example ID {EXAMPLE_ID}")
        analyze_specific_example(file_path=file_path, example_id=EXAMPLE_ID)
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# I know you’re busy
# I know you are busy
# Sorry to disturb you
# I’ll keep this short
# I will keep this short
# Just following up
# Just follow up
# Thoughts?
# Waiting on your response
# Waiting for your response
# Waiting for a response
# Add value
# If it’s not too much trouble
# I apologize in advance for bothering you
# Touching base
# Catching up
# Hoping to connect
# Hope to connect
# Can I ask a favor?
# To whom it may concern
# Did you know
# My name is
# I work for
# Did you find what you were looking for?
# I’ve been thinking
# I have been thinking
# Looking forward to hearing from you
# Looking forward to chatting
# Circling back
#
# The current date is Thursday, July 24, 2025.
# User Prompt:
#
# Prospect's personal info is provided in the following JSON.
# {
#   "Recipient's Company Information": "Paytronix, part of Access Group, offers a cloud-based digital guest engagement platform for the hospitality sector. Serving over 1,800 brands across 50,000 sites, it provides loyalty programs, online ordering, and mobile apps to enhance customer experiences. With over 20 years of expertise, Paytronix helps businesses maximize guest value and profitability. Works in the Computer Software industry. Size of the company is 201. Company is based in 80 Bridge Street, Newton, MA, 02458, US. Company was founded in 2001.",
#   "Relevant company news": [
#     {
#       "url": "https://www.theglobeandmail.com/investing/markets/markets-news/GlobeNewswire/33144172/paytronix-partners-with-auphan-software-to-expand-canadian-footprint-drive-interoperability-for-smb-operators/",
#       "title": "Paytronix Partners with Auphan Software to Expand Canadian Footprint; Drive Interoperability for SMB Operators",
#       "description": "NEWTON, Mass. and VANCOUVER, British Columbia, July 01, 2025 (GLOBE NEWSWIRE) -- Paytronix, an Access Group company and leader in guest...",
#       "publishedAt": "2025-07-03T11:46:31.154Z",
#       "isRelevant": true
#     },
#     {
#       "url": "https://www.globenewswire.com/news-release/2025/06/03/3092814/0/en/Paytronix-Announces-Nonita-Verma-as-New-GM-Changes-to-Executive-Structure.html",
#       "title": "Paytronix Announces Nonita Verma as New GM, Changes to Executive Structure",
#       "description": "Paytronix, an Access Group company, and the leader in guest engagement for restaurants and convenience stores, has announced the appointment of technology...",
#       "publishedAt": "2025-06-24T11:46:31.154Z",
#       "isRelevant": true
#     },
#     {
#       "url": "https://thewisemarketer.com/parched-hospitality-group-puts-the-guest-experience-first-with-new-paytronix-rewards-app/",
#       "title": "Parched Hospitality Group Puts the Guest Experience First with New Paytronix Rewards App",
#       "description": "Paytronix, the leader in guest engagement for restaurants and convenience stores, and Australian culture inspired Parched Hospitality Group...",
#       "publishedAt": "2025-05-28T00:00:00.000Z",
#       "isRelevant": true
#     },
#     {
#       "url": "https://www.globenewswire.com/news-release/2025/05/12/3079165/0/en/Paytronix-Upgrades-In-App-Navigation-for-Guests-with-Interstitials-Deep-Linking-Messages.html",
#       "title": "Paytronix Upgrades In-App Navigation for Guests with Interstitials, Deep Linking Messages",
#       "description": "Paytronix, the leader in guest engagement for restaurants and convenience stores, today announced the launch of two new features to its branded mobile app.",
#       "publishedAt": "2025-05-12T00:00:00.000Z",
#       "isRelevant": true
#     },
#     {
#       "url": "https://www.globenewswire.com/news-release/2025/04/16/3062614/0/en/Paytronix-2025-Loyalty-Report-Finds-Loyalty-Check-Sizes-Growing-But-Not-Universally.html",
#       "title": "Paytronix 2025 Loyalty Report Finds Loyalty Check Sizes Growing, But Not Universally",
#       "description": "Paytronix 2025 Loyalty Report Finds Loyalty Check Sizes Growing, But Not Universally · AI-enhanced data analytics, qualitative behavior feedback...",
#       "publishedAt": "2025-04-16T00:00:00.000Z",
#       "isRelevant": true
#     }
#   ],
#   "Recipient": "Stephanie Walther, CPA, CFE",
#   "Recipient Company Name": "Paytronix",
#   "Recipient's Job Title": "Financial Controller",
#   "Sender's Name": "Kirsten Orzechowski",
#   "Sender's Company": "https://www.regie.ai/",
#   "Sender's Job Title": "MM SDR",
#   "Value Proposition of Sender's Company": "Agents consolidate multiple prospecting tools into one platform, saving costs and streamlining workflow.",
#   "Problem Solved by Sender's Company": "Sales teams struggle with too many prospecting tools, hindering productivity.",
#   "Persona": "Operations Leader (BTL)"
# }
# From the above json, use the recipient's information for personalization .
#
# You should use the following instructions to write the email.
#
# Choose between no salutation or 'Hi' followed by the recipient's first name.
#
# **First Paragraph**:
# - Begin by referencing a specific aspect of the recipient's work history or current role that aligns with a common challenge they may be facing. For example:
# "I noticed that in your role as [Job Title] at [Company], you’re likely reporting on your subscription revenue which involves complex, manual Excel work"
# Other areas you can bring up that Vena helps with are: budgeting, cash flow planning, financial modeling or subscription revenue planning.
# - Do not ask for confirmation on the pain point with something presumptuous. Avoid ending the paragraph with a question.
#
# **Second Paragraph**:
# - Link their current role to a specific pain point they may be experiencing. Focus on how this challenge affects their workflow, decision-making, or overall efficiency when it comes to financial process. For example:
# "Excel is great because of the flexibility it provides, but Excel alone can lead to other problems like version control, broken links, and difficulty collaborating with other stakeholders."
# "Subscription Revenue Planning: Forecast and manage subscription revenues using top-down planning and bottom up planning templates. Leverage a granular approach with the bottom up planning template to project revenue based on the various factors of growth; customer segments, user adoption, churn and expansion. Utilize the top-down planning templated on a broader perspective to project SaaS subscription revenue by estimating market-share goals, average revenue per user, and macro level insights."
#
# **Third Paragraph**:
# Explain how Vena solves the Pain Point. Be very specific, using the Value Proposition and mention that Vena works with Sprout Social, Nutanix, Thomas International, and more.
# For example: "Vena's platform solved this for Sprout Social, cutting their monthly reporting down from 3 days to 1 hour without replacing Excel."
#
# **Fourth Paragraph**:
# Provide a short, soft and, concise call-to-action. "Mind if I share a bit more?"
#
# The entire email should be written in en-US, using straightforward but not generic language.
# Starting evaluation...
# Evaluating Hallucination Detection...
# HI score: 0 — reason: The email uses recipient details (name, title, company) from the JSON. Claims about tracking ARR, churn, etc., align with subscription revenue planning for a Financial Controller in a SaaS-like compan
# Evaluating CTA quality...
# Evaluating language quality...
# Evaluating personalization...
# Evaluating human-likeness...
# Evaluating instruction adherence...
#
# Evaluation complete!
# 💰 Cost: $0.0039
# 📊 Tokens: 8088 in / 4491 out
# 🔄 API Calls: 6
# ⏱️ Runtime: 26.83 seconds
#
# ================================================================================
# 📧 EVALUATING EXAMPLE 9
# Recipient: Unknown - Unknown
# ================================================================================
#
# 📧 EMAIL BEING EVALUATED:
# --------------------------------------------------------------------------------
# Hi Stephen,
#
# Expanding translation and localization while keeping tech systems smooth must be key for you.
#
# When I speak with other CTOs in the software industry, they often mention how hard it is to deliver quick, personalized service across multiple channels. We help teams solve this by giving their users one platform that works globally and scales as they grow.
#
# Would you be open to a quick chat to see if this fits your goals?
#
# Thanks,
# Lauren
# --------------------------------------------------------------------------------
#
# 📋 EVALUATION CONTEXT:
# Recipient Data: {"Recipient's Career Summary": 'Headquartered in Minneapolis, MN, United Language Group is a company that provides translation, localization, and interpreting. The company was established in 2015.', 'Recipient': 'Stephen Torgeson', "Recipient's Job Title": 'Executive Vice President and Chief Technology Officer', "Sender's Name": 'Lauren', "Sender's Calendar URL": 'https://outlook.office365.com/owa/calendar/5b8173b10ccf4d3db92bc1cd4cfeb90c@ringcentral.com/cacea80b7eb141968c6ec0f7cf89219d16919362514695321101/calendar.html', "Sender's Company": 'RingCentral', "Sender's Job Title": 'Business Development Representative', "Value Proposition of Sender's Company": 'RingCentral offers scalable, global, cloud-based communication solutions that grow with the business, ensuring seamless adoption and high usage through user-friendly interfaces and robust support.', 'About Sender Company': 'By choosing RingCX, you will empower your call center to provide an unparalleled client experience, streamline operations, and ensure compliance with legal industry standards.', "Problem Solved by Sender's Company": 'Customers today expect quick, personalized, and seamless service on their preferred channel. Meeting these high expectations consistently is a significant challenge.'}
# Context: No context
# Instructions: You are an expert at writing concise, convincing sales messaging, able to weave together data into a story in a single email (excluding the subject). Write the email at a 8th-grade reading level so that everyone can understand.  Remember, the goal of the email is to book a meeting.  Avoid observations for information greater than 12 months old.
#
# Use fields from the provided JSON content data to ensure accuracy.
#
# Strictly adhere to the following guidelines unless otherwise instructed:
#
# **Tone**:
# - Be curious, do not be complimentary or impressed by them. You are their peer.
#
# **Formatting**:
# - Keep the email under 90 words.
# - Do not create facts or statistics. Use only the information provided.
# - After every sentence, skip a line.
# - When using the phrase "internet industry", use "software industry" instead
# - Avoid listing company names in all capital letters, and align company name formatting to the prospect's company brand.
#
# **Salutation**:
# - Prefer "Hi" over Hey, Hello, or Dear.
# - Use only the first name in the salutation.
# - Add a new line after the salutation.
#
# **Email Body**:
# - Do not use sentences starting with "I hope," "Hope," or "As a."
# - Do not introduce yourself.
# - Add a new line after the email body, before the closing.
#
# **Signature**:
# - Do not include your name or the prospects name
# - Do not include the sender company's value proposition or slogan in the signature.
# - Cycle through the following closing keywords: "Best Regards," "Thanks," "Regards," and "Sincerely," a
# - Do not add a P.S. at the end of the email.
# - Do not add the current date at the end of the email.
# - Do not include a blank line after the closing.
# - Do not write the subject
# - Do not end with a period only a comma
# - Do not directly mention the recipient's company founding year, or number of employees in the email.
# - Do not reference work history that is more than 4 years old.
# Use short sentences. A sentence should have less than 10 words.
# Length of the opening paragraph must be less than 20 words. Split the text into multiple paragraphs if needed.
# I: You ratio should be less than 1. There should be more You's (and all variants of You's) than I's (and all variants of I's), thus focusing more on the prospect.
# The email should contain only one question, and the question should be at the end of the email.
# Do not write the subject.
# The following email cliches (and similar phrases) should not be used in the email:
# I hope this finds you well
# I hope this email finds you well
# I hope you are doing well
# I hope you’re doing well
# I hope you are well
# I hope you’re well
# I trust you’re doing well
# I trust you are doing well
# I trust you’re well
# I trust you are well
# Quick question
# Check in
# Checking in
# Reach out
# Reaching out because
# I’m sure you’re busy
# I am sure you are busy
# I am sure that you are busy
# I’m sure that you are busy
# I know you’re busy
# I know you are busy
# Sorry to disturb you
# I’ll keep this short
# I will keep this short
# Just following up
# Just follow up
# Thoughts?
# Waiting on your response
# Waiting for your response
# Waiting for a response
# Add value
# If it’s not too much trouble
# I apologize in advance for bothering you
# Touching base
# Catching up
# Hoping to connect
# Hope to connect
# Can I ask a favor?
# To whom it may concern
# Did you know
# My name is
# I work for
# Did you find what you were looking for?
# I’ve been thinking
# I have been thinking
# Looking forward to hearing from you
# Looking forward to chatting
# Circling back
#
# The current date is Tuesday, July 15, 2025.
# User Prompt:
#
# Prospect's personal info is provided in the following JSON.
# {
#   "Recipient's Career Summary": "Headquartered in Minneapolis, MN, United Language Group is a company that provides translation, localization, and interpreting. The company was established in 2015.",
#   "Recipient": "Stephen Torgeson",
#   "Recipient's Job Title": "Executive Vice President and Chief Technology Officer",
#   "Sender's Name": "Lauren",
#   "Sender's Calendar URL": "https://outlook.office365.com/owa/calendar/5b8173b10ccf4d3db92bc1cd4cfeb90c@ringcentral.com/cacea80b7eb141968c6ec0f7cf89219d16919362514695321101/calendar.html",
#   "Sender's Company": "RingCentral",
#   "Sender's Job Title": "Business Development Representative",
#   "Value Proposition of Sender's Company": "RingCentral offers scalable, global, cloud-based communication solutions that grow with the business, ensuring seamless adoption and high usage through user-friendly interfaces and robust support.",
#   "About Sender Company": "By choosing RingCX, you will empower your call center to provide an unparalleled client experience, streamline operations, and ensure compliance with legal industry standards.",
#   "Problem Solved by Sender's Company": "Customers today expect quick, personalized, and seamless service on their preferred channel. Meeting these high expectations consistently is a significant challenge."
# }
# From the above json, use the recipient's information for personalization .
#
# You should use the following instructions to write the email.
#
# Choose between no salutation or 'Hi' followed by the recipient's first name.
#
# **First Paragraph**:
# Read the Data Source to make a hyper specific positive observation that relates to how this Persona is helping contribute to their company.  Avoid obvious statements or observations.
#
# After this sentence, naturally transition into another comment about how you speak to other people in their role. Mention one of the Pain Points that you often hear from other people and ask them if they are also experiencing the issue. and provide a value prop of how you can help.
#
# **Second Paragraph**:
# Provide a short, concise call to action asking if they would like to discuss things further.
#
# - Remember, the goal is to book a qualified meeting.
#
# The entire email should be written in en-US, using straightforward but not generic language.
# Starting evaluation...
# Evaluating Hallucination Detection...
# HI score: 0 — reason: The email's claims align with the JSON: personalization uses recipient's name and role/company focus on translation/localization; pain point matches 'quick, personalized service' challenge; value prop
# Evaluating CTA quality...
# Evaluating language quality...
# Evaluating personalization...
# Evaluating human-likeness...
# Evaluating instruction adherence...
#
# Evaluation complete!
# 💰 Cost: $0.0034
# 📊 Tokens: 5161 in / 4815 out
# 🔄 API Calls: 6
# ⏱️ Runtime: 25.34 seconds
#
# ================================================================================
# 📧 EVALUATING EXAMPLE 10
# Recipient: Unknown - Unknown
# ================================================================================
#
# 📧 EMAIL BEING EVALUATED:
# --------------------------------------------------------------------------------
# Hey Timothy,
#
# I saw your team at Brinks Home is driving quality in complex systems.
# How are you managing the challenges of upgrading legacy applications while keeping processes consistent for QA?
#
# We help modernize outdated systems so change feels natural.
# For example, we worked with Cornerstone Building Brands to replace 4,000+ network devices and standardize operations across 50 sites.
#
# Would you be open to a quick call to explore how we could do something similar for you?
#
# Best,
# --------------------------------------------------------------------------------
#
# 📋 EVALUATION CONTEXT:
# Recipient Data: {"Prospect's work history": [{'title': 'Senior Quality Assurance Engineer', 'company_name': 'Brinks Home', 'is_current_position': True}, {'title': 'Senior Quality Assurance Engineer', 'company_name': 'Brinks Home', 'description': '', 'location': '', 'is_current_position': True, 'start_date': '20213', 'end_date': '00'}, {'title': 'Associate', 'company_name': 'Allata', 'description': '', 'location': '', 'is_current_position': False, 'start_date': '20197', 'end_date': '20213'}, {'title': 'Consultant', 'company_name': 'Allata', 'description': '', 'location': 'Boise Metropolitan Area', 'is_current_position': False, 'start_date': '20192', 'end_date': '20213'}, {'title': 'Software Engineer 2 / Test case development Lead', 'company_name': 'Beyondsoft', 'description': '', 'location': 'Boise Metropolitan Area', 'is_current_position': False, 'start_date': '201010', 'end_date': '20158'}, {'title': 'Project Manager', 'company_name': 'Beyondsoft', 'description': '', 'location': 'Boise Metropolitan Area', 'is_current_position': False, 'start_date': '201010', 'end_date': '20158'}, {'title': 'test tech', 'company_name': 'manpower', 'description': '', 'location': '', 'is_current_position': False, 'start_date': '20031', 'end_date': '20061'}, {'title': 'call center rep', 'company_name': 'hp', 'description': '', 'location': '', 'is_current_position': False, 'start_date': '19971', 'end_date': '19991'}, {'title': 'call center rep', 'company_name': 'hp', 'description': '', 'location': '', 'is_current_position': False, 'start_date': '19971', 'end_date': '19991'}], 'Recipient': 'Timothy Taddicken', 'Recipient Company Name': 'Brinks Home', "Recipient's Job Title": 'Senior Quality Assurance Engineer', "Sender's Name": 'Luis', "Sender's Company": 'Insight', "Sender's Job Title": 'Account Executive', "Value Proposition of Sender's Company": 'We modernize legacy systems and introduce technologies that solve real problems, fueling a culture where transformation happens naturally and continuously.', 'About Sender Company': 'Insight Enterprises, Inc. is a Fortune 500 solutions integrator helping organizations accelerate their digital journey to modernize their business and maximize the value of technology. Insight’s technical expertise spans cloud and edge-based transformation solutions, with global scale and optimization built on 33+ years of deep partnerships with the world’s leading and emerging technology providers.', "Problem Solved by Sender's Company": 'Creating new tools and transforming legacy applications is a complex process. Building a culture that embraces modern approaches takes time and careful change management.', 'Persona': 'Software Development & Product Delivery', 'Case Study Url': 'https://www.insight.com/en_US/content-and-resources/case-studies/generative-ai-client-zero-insight-boosts-productivity-to-better-serve-clients.html', 'Case Study Title': 'Generative AI Client Zero: Insight Boosts Productivity to Better Serve Clients', 'Case Study Summary': "Insight implemented generative AI using Microsoft Azure OpenAI to enhance productivity while maintaining data security. With a rapid eight-week worldwide rollout under the internally developed policy 'InsightGPT,' employees were empowered to experiment and create transformative workflows. Use cases ranged from automating HR tasks to categorizing sales data, saving substantial time and reducing errors. Insight also launched a generative AI platform tailored to employee roles, enabling specialized models for different business needs. This innovative approach delivered efficiencies across the enterprise and deepened generative AI expertise while expanding usage to upcoming projects like chatbots and copilot tools for clients and internal teams.", 'DISC Profile': ['Medium Calculativeness']}
# Context: No context
# Instructions: You are an expert at writing concise, convincing sales messaging, able to weave together data into a story in a single email (excluding the subject).
# Use fields from the provided JSON content data to ensure accuracy.
#
# Strictly adhere to the following guidelines unless otherwise instructed
#
# **Tone**:
# - Write the mail to be friendly, conversational, and like a colleague speaking to another colleague.
# - Write at grade 5 reading level.
# - Do not use exaggeration, be careful to 'say it like it is'.
# - Avoid using exclamation marks unless absolutely required.
# - Do not use sales jargon, analogies, or rhetorical questions.
# - Do not use generic, overused, or salesy terms like 'game changer,' 'revolutionary,' or 'cutting-edge.' Instead, focus on clear, specific, and relatable language that feels natural and professional.
#
# **Formatting**:
# - Keep the email under 70 words.
# - Only write one sentence per paragraph.
# - Do not create facts or statistics. Use only the information provided.
# - Do not include asterisks in the email.
# - Do not bold or highlight any of the text in the email.
#
# **Date Source Instructions**
# - Do not directly mention the recipient's company founding year, or number of employees in the email.
# - Do not reference work history that is more than 4 years old.
#
# **Salutation**:
# - Prefer "Hey" over Hi, Hello, or Dear.
# - Use only the first name in the salutation.
# - Add a new line after the salutation.
#
# **Email Body**:
# - Do not use sentences starting with "I hope," "Hope," or "As a."
# - Do not introduce yourself.
# - Add a new line after the email body, before the closing.
# - End with a clear, simple CTA (a quick call or meeting). Make the next step easy to follow. Avoid using words like spare, request, etc.
#
# **Signature**:
# - Do not include a signature in the message.
# - Do not put the sender name at the end of the email or after the closing line.
# - Cycle through the following closing keywords: "Best," "Thanks," "Regards."
# Use short sentences. A sentence should have less than 10 words.
# Length of the opening paragraph must be less than 20 words. Split the text into multiple paragraphs if needed.
# I: You ratio should be less than 1. There should be more You's (and all variants of You's) than I's (and all variants of I's), thus focusing more on the prospect.
# The email should contain only one question, and the question should be at the end of the email.
# Do not write the subject.
# The following email cliches (and similar phrases) should not be used in the email:
# I hope this finds you well
# I hope this email finds you well
# I hope you are doing well
# I hope you’re doing well
# I hope you are well
# I hope you’re well
# I trust you’re doing well
# I trust you are doing well
# I trust you’re well
# I trust you are well
# Quick question
# Check in
# Checking in
# Reach out
# Reaching out because
# I’m sure you’re busy
# I am sure you are busy
# I am sure that you are busy
# I’m sure that you are busy
# I know you’re busy
# I know you are busy
# Sorry to disturb you
# I’ll keep this short
# I will keep this short
# Just following up
# Just follow up
# Thoughts?
# Waiting on your response
# Waiting for your response
# Waiting for a response
# Add value
# If it’s not too much trouble
# I apologize in advance for bothering you
# Touching base
# Catching up
# Hoping to connect
# Hope to connect
# Can I ask a favor?
# To whom it may concern
# Did you know
# My name is
# I work for
# Did you find what you were looking for?
# I’ve been thinking
# I have been thinking
# Looking forward to hearing from you
# Looking forward to chatting
# Circling back
#
# The current date is Wednesday, July 30, 2025.
# User Prompt:
#
# Prospect's personal info is provided in the following JSON.
# {
#   "Prospect's work history": [
#     {
#       "title": "Senior Quality Assurance Engineer",
#       "company_name": "Brinks Home",
#       "is_current_position": true
#     },
#     {
#       "title": "Senior Quality Assurance Engineer",
#       "company_name": "Brinks Home",
#       "description": "",
#       "location": "",
#       "is_current_position": true,
#       "start_date": "20213",
#       "end_date": "00"
#     },
#     {
#       "title": "Associate",
#       "company_name": "Allata",
#       "description": "",
#       "location": "",
#       "is_current_position": false,
#       "start_date": "20197",
#       "end_date": "20213"
#     },
#     {
#       "title": "Consultant",
#       "company_name": "Allata",
#       "description": "",
#       "location": "Boise Metropolitan Area",
#       "is_current_position": false,
#       "start_date": "20192",
#       "end_date": "20213"
#     },
#     {
#       "title": "Software Engineer 2 / Test case development Lead",
#       "company_name": "Beyondsoft",
#       "description": "",
#       "location": "Boise Metropolitan Area",
#       "is_current_position": false,
#       "start_date": "201010",
#       "end_date": "20158"
#     },
#     {
#       "title": "Project Manager",
#       "company_name": "Beyondsoft",
#       "description": "",
#       "location": "Boise Metropolitan Area",
#       "is_current_position": false,
#       "start_date": "201010",
#       "end_date": "20158"
#     },
#     {
#       "title": "test tech",
#       "company_name": "manpower",
#       "description": "",
#       "location": "",
#       "is_current_position": false,
#       "start_date": "20031",
#       "end_date": "20061"
#     },
#     {
#       "title": "call center rep",
#       "company_name": "hp",
#       "description": "",
#       "location": "",
#       "is_current_position": false,
#       "start_date": "19971",
#       "end_date": "19991"
#     },
#     {
#       "title": "call center rep",
#       "company_name": "hp",
#       "description": "",
#       "location": "",
#       "is_current_position": false,
#       "start_date": "19971",
#       "end_date": "19991"
#     }
#   ],
#   "Recipient": "Timothy Taddicken",
#   "Recipient Company Name": "Brinks Home",
#   "Recipient's Job Title": "Senior Quality Assurance Engineer",
#   "Sender's Name": "Luis",
#   "Sender's Company": "Insight",
#   "Sender's Job Title": "Account Executive",
#   "Value Proposition of Sender's Company": "We modernize legacy systems and introduce technologies that solve real problems, fueling a culture where transformation happens naturally and continuously.",
#   "About Sender Company": "Insight Enterprises, Inc. is a Fortune 500 solutions integrator helping organizations accelerate their digital journey to modernize their business and maximize the value of technology. Insight’s technical expertise spans cloud and edge-based transformation solutions, with global scale and optimization built on 33+ years of deep partnerships with the world’s leading and emerging technology providers.",
#   "Problem Solved by Sender's Company": "Creating new tools and transforming legacy applications is a complex process. Building a culture that embraces modern approaches takes time and careful change management.",
#   "Persona": "Software Development & Product Delivery",
#   "Case Study Url": "https://www.insight.com/en_US/content-and-resources/case-studies/generative-ai-client-zero-insight-boosts-productivity-to-better-serve-clients.html",
#   "Case Study Title": "Generative AI Client Zero: Insight Boosts Productivity to Better Serve Clients",
#   "Case Study Summary": "Insight implemented generative AI using Microsoft Azure OpenAI to enhance productivity while maintaining data security. With a rapid eight-week worldwide rollout under the internally developed policy 'InsightGPT,' employees were empowered to experiment and create transformative workflows. Use cases ranged from automating HR tasks to categorizing sales data, saving substantial time and reducing errors. Insight also launched a generative AI platform tailored to employee roles, enabling specialized models for different business needs. This innovative approach delivered efficiencies across the enterprise and deepened generative AI expertise while expanding usage to upcoming projects like chatbots and copilot tools for clients and internal teams.",
#   "DISC Profile": [
#     "Medium Calculativeness"
#   ]
# }
# From the above json, use the recipient's information for personalization .
#
# You should use the following instructions to write the email.
#
# You are writing a personalized, cold outbound email. You are an expert at writing concise, convincing sales messaging.
#
# First Paragraph:
#
# Use the data source to reference a specific piece of news and correlate it to a /\{{pain point}} relevant to the persona of the prospect. You should use this to ask a compelling question that is related to the pain point without sounding pushy.
#
# Second paragraph:
#
# Staying on theme from the observation from the first paragraph, explain how our / \{{value proposition}} can solve the /\{{pain point}} referenced in the first paragraph by incorporatin the social proof on how we helped Cornerstone Building Brands consolidate and modernize IT infrastructure, replacing over 4,000 network devices to standardize networking across more than 50 sites for Cornerstone Building Brands
#
# Third paragraph:
# Ask if they would be interested in learning how we could achieve similar transformation for their business.
#
# The entire email should be written in en-US, using straightforward but not generic language.
# Starting evaluation...
# Evaluating Hallucination Detection...
# HI score: 0 — reason: The email's claims are supported by the JSON (recipient details, role, company, value proposition) and the user prompt's instructions (personalization to QA role, legacy systems pain point, and specif
# Evaluating CTA quality...
# Evaluating language quality...
# Evaluating personalization...
# Evaluating human-likeness...
# Evaluating instruction adherence...
#
# Evaluation complete!
# 💰 Cost: $0.0035
# 📊 Tokens: 7269 in / 4055 out
# 🔄 API Calls: 6
# ⏱️ Runtime: 23.57 seconds
#
# ================================================================================
# 📧 EVALUATING EXAMPLE 11
# Recipient: Unknown - Unknown
# ================================================================================
#
# 📧 EMAIL BEING EVALUATED:
# --------------------------------------------------------------------------------
# Hey Dipshikha,
#
# Noticed the Marketing team at Randstad Digital US were in talks with Highspot a little while ago regarding enhancing sales plays, but looks like the timing did not work out then.
#
# I read the notes of the call and saw there was potential value to the Marketing team, with Highspot being able to help with:
# - Aligning marketing and sales on content needs
# - Reducing underused or underperforming content
# - Closing gaps in messaging across go-to-market teams
#
# I know it has been some time, but would you be open to learning how Highspot helps drive adoption of sales playbooks and new GTM selling motions with our sales enablement platform?
#
# Would you be opposed to me providing some tentative times for us to have an introductory chat?
#
# Best Regards,
# Adam
# Highspot
# --------------------------------------------------------------------------------
#
# 📋 EVALUATION CONTEXT:
# Recipient Data: {"Prospect's work history": [{'title': 'Director Marketing Communications', 'company_name': 'Randstad Digital US', 'is_current_position': True}, {'company_name': 'Randstad Digital US', 'is_current_position': True}, {'title': 'Senior Communications Manager', 'company_name': 'HCL Technologies', 'is_current_position': False, 'start_date': 'May 2020', 'end_date': 'September 2021'}, {'title': 'Assistant Editor', 'company_name': 'Hindustan Times', 'is_current_position': False, 'start_date': 'September 2009', 'end_date': 'September 2018'}, {'title': 'Marketing Lead (Europe)', 'company_name': 'Mindtree', 'is_current_position': False, 'start_date': 'July 2022', 'end_date': 'November 2022'}, {'title': 'Group Communications Manager', 'company_name': 'HCL Technologies', 'is_current_position': False, 'start_date': 'September 2021', 'end_date': 'June 2022'}, {'title': 'Marketing Lead (Europe)', 'company_name': 'LTIMindtree', 'is_current_position': False, 'start_date': 'November 2022', 'end_date': 'July 2024'}, {'title': 'Copy Editor', 'company_name': 'Metro Now', 'is_current_position': False, 'start_date': 'November 2006', 'end_date': 'December 2008'}, {'title': 'Assistant Editor', 'company_name': 'The New Indian Express', 'is_current_position': False, 'start_date': 'December 2018', 'end_date': 'April 2020'}], 'Recipient': 'Dipshikha Bhattacharyya', 'Recipient Company Name': 'Randstad Digital US', "Recipient's Job Title": 'Director Marketing Communications', "Sender's Name": 'Adam', "Sender's Company": 'Highspot', "Sender's Job Title": 'Senior Account Development Representative - EMEA', "Value Proposition of Sender's Company": 'Highspot bridges the gap between sales and marketing, aligning efforts around revenue-driving content and delivering up to 3x ROI through tighter collaboration and feedback loops.', "Problem Solved by Sender's Company": 'Sales and marketing are misaligned on content needs, leading to underused or underperforming content, frustration with messaging that weaken the overall go-to-market execution, and missed revenue targets.', 'DISC Profile': ['High Dominance', 'High Steadiness', 'High Influence']}
# Context: No context
# Instructions: You write in business English of United Kingdom. When writing any kind of message, greetings, salutation or sign off, basically any text, use only a language appropriate for formal business communication in English of United Kingdom. Anything that doesn't follow the above instruction is incorrect. You are an expert at writing concise, convincing sales messaging, able to weave together data into a story in a single email (excluding the subject).
# Use fields from the provided JSON content data to ensure accuracy.
#
# Strictly adhere to the following guidelines unless otherwise instructed
#
# **Tone**:
# - Write the mail to be human, conversational, and authentic.
# - Write at grade 5 reading level.
# - Do not use exaggeration, be careful to 'say it like it is'.
# - Avoid using exclamation marks unless absolutely required.
# - Do not use sales jargon, analogies, or rhetorical questions.
# - Do not use generic, overused, or salesy terms like 'game changer,' 'revolutionary,' or 'cutting-edge.' Instead, focus on clear, specific, and relatable language that feels natural and professional.
#
# **Formatting**:
# - Keep the email under 90 words.
# - Skip a line after every paragraph.
# - Do not create facts or statistics. Use only the information provided.
# - Do not include asterisks in the email.
# - Do not bold or highlight any of the text in the email.
# - When referencing the recipient's "role", simplify it to one word most closely aligned to the function in the business that they oversee. For example: President = "Sales", VP of Marketing = "Marketing", Director of Enablement = "Enablement"
# - Use the short version of the persona. Eg: "Sales Enablement" not "Sales Enablement ATL".
# - Do not include ATL, OTL, or BTL when referencing the persona in the message.
# - Avoid using suffixes such as Inc, LLC, Ltd, or GmbH within the company name. Do not include dashes or slashes in the company name as well.
# - Align company name formatting to the prospect's company brand.
# - Always use the shortest possible form of the company name. Eg: “Ford Motor Company” should always be “Ford”, "Tql/tql Global" should always be "TQL".
#
# **Date Source Instructions**
# - Do not directly mention the recipient's company founding year, or number of employees in the email.
# - Do not reference work history that is more than 4 years old.
#
# **Salutation**:
# - Prefer "Hey" over Hi, Hello, or Dear.
# - Use only the first name in the salutation.
# - Add a new line after the salutation.
#
# **Email Body**:
# - Do not use sentences starting with "I hope," "Hope," or "As a."
# - Do not introduce yourself.
# - Add a new line after the email body, before the closing.
# - End with a clear, simple CTA (a quick call or meeting). Make the next step easy to follow. Avoid using words like spare, request, etc.
#
# **Signature**:
# - Closing keyword > name of sender > company of sender.
# - Use only the first name in the sign-off.
# - Add a signature at the end of the email. Do not use the words "[Signature]" or "Signature" to label it.
# - Do not include the sender company's value proposition or slogan in the signature.
# - If including the company name in the signature, add it on a new line.
# - Do not include URLs in the signature.
# - Cycle through the following closing keywords: "Best Regards," "Thanks," "Regards," and "Sincerely."
# - Do not add a P.S. at the end of the email.
# - Do not add the current date at the end of the email.
# - Do not include a blank line after the closing.
# - Do not write the subject.
# Use short sentences. A sentence should have less than 10 words.
# Length of the opening paragraph must be less than 20 words. Split the text into multiple paragraphs if needed.
# I: You ratio should be less than 1. There should be more You's (and all variants of You's) than I's (and all variants of I's), thus focusing more on the prospect.
# The email should contain only one question, and the question should be at the end of the email.
# Do not write the subject.
# The following email cliches (and similar phrases) should not be used in the email:
# I hope this finds you well
# I hope this email finds you well
# I hope you are doing well
# I hope you’re doing well
# I hope you are well
# I hope you’re well
# I trust you’re doing well
# I trust you are doing well
# I trust you’re well
# I trust you are well
# Quick question
# Check in
# Checking in
# Reach out
# Reaching out because
# I’m sure you’re busy
# I am sure you are busy
# I am sure that you are busy
# I’m sure that you are busy
# I know you’re busy
# I know you are busy
# Sorry to disturb you
# I’ll keep this short
# I will keep this short
# Just following up
# Just follow up
# Thoughts?
# Waiting on your response
# Waiting for your response
# Waiting for a response
# Add value
# If it’s not too much trouble
# I apologize in advance for bothering you
# Touching base
# Catching up
# Hoping to connect
# Hope to connect
# Can I ask a favor?
# To whom it may concern
# Did you know
# My name is
# I work for
# Did you find what you were looking for?
# I’ve been thinking
# I have been thinking
# Looking forward to hearing from you
# Looking forward to chatting
# Circling back
#
# The current date is Friday, August 01, 2025.
# User Prompt:
#
# Prospect's personal info is provided in the following JSON.
# {
#   "Prospect's work history": [
#     {
#       "title": "Director Marketing Communications",
#       "company_name": "Randstad Digital US",
#       "is_current_position": true
#     },
#     {
#       "company_name": "Randstad Digital US",
#       "is_current_position": true
#     },
#     {
#       "title": "Senior Communications Manager",
#       "company_name": "HCL Technologies",
#       "is_current_position": false,
#       "start_date": "May 2020",
#       "end_date": "September 2021"
#     },
#     {
#       "title": "Assistant Editor",
#       "company_name": "Hindustan Times",
#       "is_current_position": false,
#       "start_date": "September 2009",
#       "end_date": "September 2018"
#     },
#     {
#       "title": "Marketing Lead (Europe)",
#       "company_name": "Mindtree",
#       "is_current_position": false,
#       "start_date": "July 2022",
#       "end_date": "November 2022"
#     },
#     {
#       "title": "Group Communications Manager",
#       "company_name": "HCL Technologies",
#       "is_current_position": false,
#       "start_date": "September 2021",
#       "end_date": "June 2022"
#     },
#     {
#       "title": "Marketing Lead (Europe)",
#       "company_name": "LTIMindtree",
#       "is_current_position": false,
#       "start_date": "November 2022",
#       "end_date": "July 2024"
#     },
#     {
#       "title": "Copy Editor",
#       "company_name": "Metro Now",
#       "is_current_position": false,
#       "start_date": "November 2006",
#       "end_date": "December 2008"
#     },
#     {
#       "title": "Assistant Editor",
#       "company_name": "The New Indian Express",
#       "is_current_position": false,
#       "start_date": "December 2018",
#       "end_date": "April 2020"
#     }
#   ],
#   "Recipient": "Dipshikha Bhattacharyya",
#   "Recipient Company Name": "Randstad Digital US",
#   "Recipient's Job Title": "Director Marketing Communications",
#   "Sender's Name": "Adam",
#   "Sender's Company": "Highspot",
#   "Sender's Job Title": "Senior Account Development Representative - EMEA",
#   "Value Proposition of Sender's Company": "Highspot bridges the gap between sales and marketing, aligning efforts around revenue-driving content and delivering up to 3x ROI through tighter collaboration and feedback loops.",
#   "Problem Solved by Sender's Company": "Sales and marketing are misaligned on content needs, leading to underused or underperforming content, frustration with messaging that weaken the overall go-to-market execution, and missed revenue targets.",
#   "DISC Profile": [
#     "High Dominance",
#     "High Steadiness",
#     "High Influence"
#   ]
# }
# From the above json, use the recipient's information for personalization .
#
# You should use the following instructions to write the email.
#
# Use the template provided below to craft a personalised message. Replace all placeholders with the corresponding information from the JSON data. If data does not exsist for the placeholder, leave the placeholder as a visible marker in the email, to be filled in manually later.
#
# Hi \{{first_name}},
#
# Noticed the\{{persona}} team at \{{company}} were in talks with Highspot a little while ago regarding enhancing sales plays, but looks like the timing just didn’t work out.
#
# I read the notes of the call and saw there was potential value to the PERSONA TEAM, with Highspot being able to help with:
# Challenge 1
# Challenge 2
# Challenge 3
#
# I know it’s been a while for both sides, but curious if you’d be open to learning how Highspot helps drive adoption of sales playbooks and new GTM selling motions with our sales enablement platform.
#
# Would you be opposed to me providing some tentative times for us to have an introductory chat?
#
# \{{sender’s name}}
# \{{sender’s company}}
#
# Fill in the challenges to be most relevant to their persona.
#
# The entire email should be written in English of United Kingdom, using straightforward but not generic language.
# Starting evaluation...
# Evaluating Hallucination Detection...
# HI score: 1 — reason: The email fabricates a past interaction ('in talks with Highspot' and 'read the notes of the call') for the Marketing team at Randstad Digital US, which is not mentioned or supported in the JSON or pr
# Evaluating CTA quality...
# Evaluating language quality...
# Evaluating personalization...
# Evaluating human-likeness...
# Evaluating instruction adherence...
#
# Evaluation complete!
# 💰 Cost: $0.0038
# 📊 Tokens: 7165 in / 4784 out
# 🔄 API Calls: 6
# ⏱️ Runtime: 24.91 seconds
#
# ================================================================================
# 📧 EVALUATING EXAMPLE 12
# Recipient: Unknown - Unknown
# ================================================================================
#
# 📧 EMAIL BEING EVALUATED:
# --------------------------------------------------------------------------------
# Hey Jacquie,
#
# Finding high-potential leads fast can be tough, even with a strong sales team. When opportunities slip by, it can slow revenue growth and impact targets.
#
# Regie.ai uses AI agents to find and prioritize top prospects, then engage them automatically so reps can focus on closing deals. This helps capture more opportunities without adding extra work for the team.
#
# Would it make sense to discuss how this could help KLiR hit revenue goals sooner?
#
# Best Regards,
# Giavonni
# Regie.ai
# --------------------------------------------------------------------------------
#
# 📋 EVALUATION CONTEXT:
# Recipient Data: {"Prospect's work history": [{'title': 'Chief Revenue Officer', 'company_name': 'KLiR', 'is_current_position': True}, {'company_name': 'KLiR', 'is_current_position': True}], 'Recipient': 'Jacquie Dwyer', 'Recipient Company Name': 'KLiR', "Recipient's Job Title": 'Chief Revenue Officer', "Sender's Name": 'Giavonni', "Sender's Company": 'Regie.ai', "Sender's Job Title": 'Sales Development', "Value Proposition of Sender's Company": 'Regie agents rapidly identify and engage high-potential leads, maximizing opportunity capture.', 'About Sender Company': "Regie.ai modernizes sales engagement with AI-driven prospecting. \n\nAI Agents source and prioritize contacts, generate and send personalized messages, and accelerate engagement on priority leads 100% autonomously, so reps can focus on more impactful sales activities.\n\nAutomatically prospect and book meetings for yours reps, using Regie's AI Sales Engagement Platform.", "Problem Solved by Sender's Company": "The market is full of opportunities, but the sales team isn't finding them quickly or frequently enough.", 'DISC Profile': ['High Steadiness', 'Medium Calculativeness']}
# Context: No context
# Instructions: You are an expert at writing concise, convincing sales messaging, able to weave together data into a story in a single email (excluding the subject).
# Use fields from the provided JSON content data to ensure accuracy.
#
# Strictly adhere to the following guidelines unless otherwise instructed
#
# **Tone**:
# - Write the mail to be human, conversational, and authentic.
# - Write at grade 5 reading level.
# - Do not use exaggeration, be careful to 'say it like it is'.
# - Avoid using exclamation marks unless absolutely required.
# - Do not use sales jargon, analogies, or rhetorical questions.
# - Do not use generic, overused, or salesy terms like 'game changer,' 'revolutionary,' or 'cutting-edge.' Instead, focus on clear, specific, and relatable language that feels natural and professional.
#
# **Formatting**:
# - Keep the email under 80 words.
# - Skip a line after every paragraph.
# - Do not create facts or statistics. Use only the information provided.
# - Do not include asterisks in the email.
# - Do not bold or highlight any of the text in the email.
#
# **Date Source Instructions**
# - Do not directly mention the recipient's company founding year, or number of employees in the email.
# - Do not reference work history that is more than 4 years old.
#
# **Salutation**:
# - Prefer "Hey" over Hi, Hello, or Dear.
# - Use only the first name in the salutation.
# - Add a new line after the salutation.
#
# **Email Body**:
# - Do not use sentences starting with "I hope," "Hope," or "As a."
# - Do not introduce yourself.
# - Add a new line after the email body, before the closing.
# - End with a clear, simple CTA (a quick call or meeting). Make the next step easy to follow. Avoid using words like spare, request, etc.
#
# **Signature**:
# - Closing keyword > name of sender > company of sender.
# - Use only the first name in the sign-off.
# - Add a signature at the end of the email. Do not use the words "[Signature]" or "Signature" to label it.
# - Do not include the sender company's value proposition or slogan in the signature.
# - If including the company name in the signature, add it on a new line.
# - Do not include URLs in the signature.
# - Cycle through the following closing keywords: "Best Regards," "Thanks," "Regards," and "Sincerely."
# - Do not add a P.S. at the end of the email.
# - Do not add the current date at the end of the email.
# - Do not include a blank line after the closing.
# - Do not write the subject.
# Use short sentences. A sentence should have less than 10 words.
# Length of the opening paragraph must be less than 20 words. Split the text into multiple paragraphs if needed.
# ...
# Context: No context
# Instructions: You are an expert at writing concise, convincing sales messaging, able to weave together data into a story in a single email (excluding the subject). Write the email at a 6th-grade reading level so that everyone can understand.
# Write in the English of the location of the prospect. If the prospect resides in the United States or Canada, use US English. If they reside in the United Kingdom, use British English.
# Use fields from the provided JSON content data to ensure accuracy.
# Strictly adhere to the following guidelines unless otherwise instructed:
#
# **Tone**:
# - Be curious, do not be complimentary or impressed by them. You are their peer.
# - Do not be presumptuous. For example, do not assume and add ", right?" to the end of sentences.
#
# **Formatting**:
# - Keep the email under 40 words.
# - Do not create facts or statistics. Use only the information provided.
# - After every sentence, skip a line.
#
# **Salutation**:
# - Prefer "Hi"
# - Use only the first name in the salutation.
# - Add a new line after the salutation.
#
# **Email Body**:
# - Do not use sentences starting with "I hope," "Hope," or "As a."
# - Do not introduce yourself.
# - Add a new line after the email body, before the closing.
#
# **Signature**:
# - Use only the sender's first name in the sign-off.
# - Add a signature at the end of the email. Do not use the words "[Signature]" or "Signature" to label it.
# - Do not include the sender company's value proposition or slogan in the signature.
# - Do not include URLs in the signature.
# - Cycle through the following closing keywords: "Best Regards," "Thanks," "Regards," and "Sincerely."
# - Do not add a P.S. at the end of the email.
# - Do not add the current date at the end of the email.
# - Do not include a blank line after the closing.
# - Do not write the subject.
# Use short sentences. A sentence should have less than 10 words.
# Length of the opening paragraph must be less than 20 words. Split the text into multiple paragraphs if needed.
# I: You ratio should be less than 1. There should be more You's (and all variants of You's) than I's (and all variants of I's), thus focusing more on the prospect.
# The email should contain only one question, and the question should be at the end of the email.
# Do not write the subject.
# The following email cliches (and similar phrases) should not be used in the email:
# I hope this finds you well
# I hope this email finds you well
# I hope you are doing well
# I hope you’re doing well
# I hope you are well
# I hope you’re well
# I trust you’re doing well
# I trust you are doing well
# I trust you’re well
# I trust you are well
# Quick question
# Check in
# Checking in
# Reach out
# Reaching out because
# I’m sure you’re busy
# I am sure you are busy
# I am sure that you are busy
# I’m sure that you are busy
# I know you’re busy
# I know you are busy
# Sorry to disturb you
# I’ll keep this short
# I will keep this short
# Just following up
# Just follow up
# Thoughts?
# Waiting on your response
# Waiting for your response
# Waiting for a response
# Add value
# If it’s not too much trouble
# I apologize in advance for bothering you
# Touching base
# Catching up
# Hoping to connect
# Hope to connect
# Can I ask a favor?
# To whom it may concern
# Did you know
# My name is
# I work for
# Did you find what you were looking for?
# I’ve been thinking
# I have been thinking
# Looking forward to hearing from you
# Looking forward to chatting
# Circling back
#
# The current date is Friday, August 01, 2025.
# User Prompt:
#
# Prospect's personal info is provided in the following JSON.
# {
#   "Prospect's work history": [
#     {
#       "title": "Chief Financial Officer",
#       "company_name": "Opus One Winery LLC",
#       "is_current_position": true
#     },
#     {
#       "company_name": "Opus One Winery LLC",
#       "is_current_position": true
#     },
#     {
#       "title": "Vice President, Finance",
#       "company_name": "Delicato Family Vineyards",
#       "is_current_position": false,
#       "start_date": "March 2001",
#       "end_date": "October 2015"
#     },
#     {
#       "title": "Vice President, Financial Planning & Analysis",
#       "company_name": "Winery Exchange",
#       "is_current_position": false,
#       "start_date": "October 2015",
#       "end_date": "December 2019"
#     },
#     {
#       "title": "Marketing Manager",
#       "company_name": "Internet Start Up Tavolo.com",
#       "is_current_position": false,
#       "start_date": "1998",
#       "end_date": "2000"
#     },
#     {
#       "title": "Packaging, Product Development Group Leader",
#       "company_name": "Kraft General Foods - Maxwell House Coffee Division",
#       "is_current_position": false,
#       "start_date": "1987",
#       "end_date": "1998"
#     }
#   ],
#   "Recipient": "Mike Delonis",
#   "Recipient Company Name": "Opus One Winery LLC",
#   "Recipient's Job Title": "Chief Financial Officer",
#   "Sender's Name": "Niall",
#   "Sender's Company": "Vena",
#   "Sender's Job Title": "SDR",
#   "Value Proposition of Sender's Company": "It is time-consuming and error-prone to collect data across your business units and different source systems to create a single source of truth.",
#   "About Sender Company": "Vena’s Complete FP&A Platform empowers teams to plan better and act faster using native Excel as the user interface. Unlike rigid legacy systems, Vena enhances collaboration, reduces manual work, and supports strategic decision-making with AI-powered insights via Vena Copilot. Vena unifies data collection and aggregation from your disparate systems for real-time analysis and scalable planning. Vena supports budgeting, forecasting, reporting, and strategic planning across the business—without disrupting workflows. With deep Microsoft integration and expert support, Vena helps organizations achieve more with intuitive, integrated FP&A.",
#   "Problem Solved by Sender's Company": "Vena has solves Excel issues that finance teams come across on a day to day basis, such as version control, lack of integrations with existing systems and time consuming manual work.",
#   "DISC Profile": [
#     "High Influence"
#   ]
# }
# From the above json, use the recipient's information for personalization .
#
# You should use the following instructions to write the email.
#
# Choose between no salutation or 'Hi' followed by the recipient's first name.
#
# **First Paragraph**:
# - Begin by referencing a specific aspect of the recipient's work history or current role that aligns with a common challenge they may be facing.
# - For example: "I noticed that in your role as [Job Title] at [Company], you’re likely managing complex financial data from multiple sources."
# - Do not mention a year or date
# - "I noticed..." or "As a..."
#
# **Second Paragraph**:
# - Link their current role to a specific pain point they may be experiencing.
# - Focus on how this challenge affects their workflow, decision-making, or overall efficiency when it comes to financial process. For example:
# "From speaking with other leaders in the retail space, I'm hearing that recent global events (e.g. inflation, a hyper-competitive labour market, supply chain issues, etc.) have put an immense amount of pressure on finance teams to leverage agile planning in order to pivot in the face of market volatility, ambiguity and complexity."
# - Try to refer their industry in a colloquial way
#
# **Third Paragraph**:
# Explain how we solve the Pain Point and mention that Vena works within the retail space with companies like Tanger Outlets, OneStop, Bol.com, Schuh, and more.
# - For example, Vena can help with the following Retail-specific financial processes:
# - Sales modelling at product line- and item-level;
# - Like-for-like calculations based on trading stores;
# - Workforce planning to determine the number of employees required by store by week based on items sold
# - When you talk about Excel, say we "use Excel as our native UI" or User Interface. Do not say we are an integration with Excel or integrate with Excel.
#
# **Fourth Paragraph**:
# Provide a short, soft and, concise call-to-action. "Mind if I share more?" or "Does this sound helpful?
#
# The entire email should be written in en-US, using straightforward but not generic language.
# Starting evaluation...
# Evaluating Hallucination Detection...
# HI score: 0 — reason: The email accurately references the recipient's role and company from the JSON. Pain points align with the value proposition and problem solved in the JSON. Vena's features and Excel usage match the '
# Evaluating CTA quality...
# Evaluating language quality...
# Evaluating personalization...
# Evaluating human-likeness...
# Evaluating instruction adherence...
#
# Evaluation complete!
# 💰 Cost: $0.0040
# 📊 Tokens: 6660 in / 5328 out
# 🔄 API Calls: 6
# ⏱️ Runtime: 28.86 seconds
#
#
# ================================================================================
# 📊 TEST RESULTS SUMMARY
# ================================================================================
#  example_id  overall_score  acceptable  hallucination  cta_quality  language_quality  personalization  human_likeness  instruction_adherence  cost_usd
#           1            4.6        True              0            5                 5                4               5                      4    0.0033
#           2            4.8        True              0            5                 5                5               5                      4    0.0039
#           3            3.6        True              0            4                 5                1               5                      3    0.0035
#           4            4.4        True              0            5                 5                4               5                      3    0.0029
#           5            4.2        True              0            5                 5                4               4                      3    0.0037
#           6            4.6        True              0            5                 5                5               5                      3    0.0033
#           7            4.4        True              0            5                 5                4               5                      3    0.0032
#           8            4.0        True              0            4                 5                4               5                      2    0.0039
#           9            4.4        True              0            5                 5                4               5                      3    0.0034
#          10            4.4        True              0            5                 5                4               5                      3    0.0035
#          11            4.6       False              1            5                 5                5               5                      3    0.0038
#          12            4.4        True              0            5                 5                4               5                      3    0.0033
#          13            4.0        True              0            5                 5                3               4                      3    0.0037
#          14            4.4        True              0            5                 5                3               5                      4    0.0037
#          15            4.2        True              0            5                 5                2               5                      4    0.0032
#          16            3.8        True              0            5                 5                1               5                      3    0.0038
#          17            4.0        True              0            5                 5                2               5                      3    0.0038
#          18            4.6       False              1            4                 5                5               5                      4    0.0033
#          19            4.2        True              0            5                 5                3               5                      3    0.0036
#          20            4.6        True              0            5                 5                5               5                      3    0.0038
#          21            4.6        True              0            5                 5                5               5                      3    0.0033
#          22            4.6        True              0            5                 5                4               5                      4    0.0040
#          23            4.4        True              0            5                 5                4               5                      3    0.0032
#          24            4.4        True              0            5                 5                4               5                      3    0.0038
#          25            4.0        True              0            5                 4                3               5                      3    0.0032
#          26            4.0        True              0            5                 5                2               5                      3    0.0033
#          27            4.2        True              0            5                 5                3               5                      3    0.0035
#          28            4.6        True              0            5                 5                4               5                      4    0.0029
#          29            4.2        True              0            5                 5                3               5                      3    0.0032
#          30            4.4        True              0            5                 5                5               5                      2    0.0040
#
# ================================================================================
# 💰 Total Cost: $0.1050
# 💰 Average Cost per Email: $0.0035
# 💰 Estimated Cost for 10,000 emails: $35.00
#
# 📈 Average Overall Score: 4.32/10
# ✅ Acceptable Emails: 28/30 (93%)
# ================================================================================
